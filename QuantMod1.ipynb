# %%
options(warn=-1)
options("getSymbols.warning4.0"=FALSE)
suppressMessages(library(quantmod))

# %%
getSymbols('SCHG')
#print(periodReturn(SCHG['2019-01-01/2020-05-06']))
# Out:
# [1] "SCHG"

# %%
period <- '2019-01-01/2020-05-06'
seriesHi(SCHG[period])
# Out:
#            SCHG.Open SCHG.High SCHG.Low SCHG.Close SCHG.Volume SCHG.Adjusted
# 2020-02-19    102.01    102.61      102     102.34      327800      102.1141

# %%
seriesLo(SCHG[period])
# Out:
#            SCHG.Open SCHG.High SCHG.Low SCHG.Close SCHG.Volume SCHG.Adjusted
# 2019-01-03     68.19     68.27    66.72      66.84     1112300      66.08884

# %%
Lag(Cl(SCHG['2020']),k=1:3)
# Out:
#             Lag.1  Lag.2  Lag.3
# 2020-01-02     NA     NA     NA
# 2020-01-03  94.15     NA     NA
# 2020-01-06  93.63  94.15     NA
# 2020-01-07  94.22  93.63  94.15
# 2020-01-08  94.09  94.22  93.63
# 2020-01-09  94.75  94.09  94.22
# 2020-01-10  95.62  94.75  94.09
# 2020-01-13  95.47  95.62  94.75
# 2020-01-14  96.21  95.47  95.62
# 2020-01-15  95.88  96.21  95.47
# 2020-01-16  96.22  95.88  96.21
# 2020-01-17  97.16  96.22  95.88
# 2020-01-21  97.49  97.16  96.22
# 2020-01-22  97.57  97.49  97.16
# 2020-01-23  97.56  97.57  97.49
# 2020-01-24  97.77  97.56  97.57
# 2020-01-27  96.98  97.77  97.56
# 2020-01-28  95.37  96.98  97.77
# 2020-01-29  96.67  95.37  96.98
# 2020-01-30  96.87  96.67  95.37
# 2020-01-31  97.18  96.87  96.67
# 2020-02-03  95.50  97.18  96.87
# 2020-02-04  96.68  95.50  97.18
# 2020-02-05  98.46  96.68  95.50
# 2020-02-06  98.85  98.46  96.68
# 2020-02-07  99.46  98.85  98.46
# 2020-02-10  99.03  99.46  98.85
# 2020-02-11 100.16  99.03  99.46
# ...
